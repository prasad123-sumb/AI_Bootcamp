# %%
#1
import sys 
print(sys.version)
# Out:
# 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]

# %%
#2
import pandas as pd  
file_path = "Downloads\student_performance.csv"  
df = pd.read_csv(file_path)    
print(df.head())
# Out:
#    StudentID  G1  G2  G3      Mjob     Fjob  age address  studytime  failures  \
# 0          1   6   2   2   teacher  at_home   21   rural          3         1
# 1          2  19  11  18    health  teacher   18   rural          1         1
# 2          3  14   7  19    health    other   20   urban          1         1
# 3          4  10   2   6  services   health   21   urban          3         1
# 4          5   7   0  19    health   health   18   rural          4         1
#
#   schoolsup famsup paid activities nursery higher internet romantic
# 0        no    yes  yes        yes     yes    yes       no      yes
# 1        no     no   no         no     yes     no       no       no
# 2       yes    yes  yes         no      no     no      yes      yes
# 3       yes     no  yes         no     yes     no       no       no
# 4        no     no  yes         no     yes    yes      yes       no
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# ...

# %%
#3
import pandas as pd
file_path = "Downloads\student_performance.csv"   
df = pd.read_csv(file_path) 
print("Column Data Types:") 
print(df.dtypes)
# Out:
# Column Data Types:
# StudentID      int64
# G1             int64
# G2             int64
# G3             int64
# Mjob          object
# Fjob          object
# age            int64
# address       object
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# dtype: object
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\HP\AppData\Local\Temp\ipykernel_15228\1321820950.py:3: SyntaxWarning: invalid escape sequence '\s'
#   file_path = "Downloads\student_performance.csv"

# %%
#4
import pandas as pd
file_path = "Downloads\student_performance.csv" 
df = pd.read_csv(file_path)
missing_rows = df.isnull().any(axis=1).sum()
print(f"Number of rows with missing data: {missing_rows}")
# Out:
# Number of rows with missing data: 0
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\HP\AppData\Local\Temp\ipykernel_15228\1130080515.py:3: SyntaxWarning: invalid escape sequence '\s'
#   file_path = "Downloads\student_performance.csv"

# %%
#5
import pandas as pd 
from statistics import mode  

floc = "Downloads\ipl_matches_smalldata.csv" 
ipl_df = pd.read_csv(floc)  
top_players = ipl_df.groupby("batter")["batsman_runs"].sum().nlargest(10) 
mean_runs = top_players.mean()
mode_runs = mode(top_players)

print("Mean Runs Scored by Top 10 Players:", mean_runs) 
print("Mode Runs Scored by Top 10 Players:", mode_runs)
# Out:
# Mean Runs Scored by Top 10 Players: 167.1
# Mode Runs Scored by Top 10 Players: 189
# <>:5: SyntaxWarning: invalid escape sequence '\i'
# <>:5: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\HP\AppData\Local\Temp\ipykernel_15228\3947912657.py:5: SyntaxWarning: invalid escape sequence '\i'
#   floc = "Downloads\ipl_matches_smalldata.csv"

# %%
#6
import pandas as pd 

floc = "Downloads\ipl_matches_smalldata.csv" 
ipl_df = pd.read_csv(floc)  
players_total_runs = df.groupby("batter")["batsman_runs"].sum()

players_above_500 = players_total_runs[players_total_runs > 500]

print("Players who scored more than 500 runs:")
print(players_above_500)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\i'
# <>:3: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\HP\AppData\Local\Temp\ipykernel_15228\851078045.py:3: SyntaxWarning: invalid escape sequence '\i'
#   floc = "Downloads\ipl_matches_smalldata.csv"
# C:\Users\HP\AppData\Local\Temp\ipykernel_15228\851078045.py:3: SyntaxWarning: invalid escape sequence '\i'
#   floc = "Downloads\ipl_matches_smalldata.csv"
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 5
#       3 floc = "Downloads\ipl_matches_smalldata.csv"
#       4 ipl_df = pd.read_csv(floc)
# ----> 5 players_total_runs = df.groupby("batter")["batsman_runs"].sum()
#       7 # Filter players who have scored more than 500 runs
#       8 players_above_500 = players_total_runs[players_total_runs > 500]
#
# ...

# %%
#7
import pandas as pd 
import matplotlib.pyplot as plt  

top_10_players = ipl_df.groupby("batter")["batsman_runs"].sum().nlargest(10) 
plt.figure(figsize=(8, 5)) 
top_10_players.plot(kind="bar", color="black", edgecolor="green")

plt.xlabel("Player") 
plt.ylabel("Runs") 
plt.title("Top 10 Players by Total Runs in IPL Dataset")
plt.xticks(rotation=45) 
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
#8
# !pip install opencv-python

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2

img = cv2.imread(r"Download\bike.jpg")
print(type(img))    

cv2.imshow("bike.jpg",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
print(img.shape)   

img_resize = cv2.resize(img,(400,256))    
cv2.imshow("bike",img_resize)
cv2.waitKey(0)
cv2.destroyAllWindows()
print(img_resize.shape)   

img_flip = cv2.flip(img,1)  
img_flip = cv2.flip(img,-1) 
cv2.imshow("flipped Image",img_flip)
cv2.waitKey(0)
cv2.destroyAllWindows()

img_crop = img[100:300,200:500]   
cv2.imshow("Cropped img",img_crop)
cv2.waitKey(0)
cv2.destroyAllWindows()     
cv2.imwrite(r"croppedimg.jpg",img_crop)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# <class 'NoneType'>
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[46], line 12
#       9 img = cv2.imread(r"Download\bike.jpg")
#      10 print(type(img))
# ---> 12 cv2.imshow("bike.jpg",img)
#      13 cv2.waitKey(0)
#      14 cv2.destroyAllWindows()
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:973: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#9
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
df = pd.read_csv("Downloads/tips.csv")

# Display the first 30 rows
print(df.head(30))

# Save the DataFrame to a CSV file
df.to_csv('tips.csv', index=False)

# Check if 'Smoking' column exists
if 'Smoking' in df.columns:
    # Pie chart
    smoking_counts = df['Smoking'].value_counts()
    plt.pie(smoking_counts, labels=smoking_counts.index, autopct='%1.1f%%', startangle=140)
    plt.title('Percentage of Smoking vs Non-Smoking Customers')
    plt.show()
else:
    print("Column 'Smoking' not found in the dataset.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 6
#       3 import matplotlib.pyplot as plt
#       5 # Load the CSV file
# ----> 6 df = pd.read_csv("Downloads/tips.csv")
#       8 # Display the first 30 rows
#       9 print(df.head(30))
#
# ...

# %%
#10
# !pip install wordcloud
# Import necessary libraries
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter

# Ensure necessary NLTK data is downloaded
nltk.download('punkt')
nltk.download('stopwords')

text = """
Sports are physical activities that involve skill, competition, and teamwork. 
They can be played individually or in teams and often require strategy, training, and practice.
Whether it's soccer, basketball, or tennis, sports help improve physical fitness, boost mental health, 
and teach important life lessons like discipline, perseverance, and teamwork. 
People of all ages enjoy sports, whether for fun, fitness, or competition.
"""
print(text)

# Tokenization of words
words = word_tokenize(text.lower())  # Convert to lowercase for uniformity
print(words)

# Remove stopwords
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.isalpha() and word not in stop_words]
# The general syntax for a list comprehension is: [expression for item in iterable if condition]
print(filtered_words)

# Frequency distribution of words
word_freq = Counter(filtered_words)
print(word_freq)

# Create a WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)

# Plotting the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Hide axes
plt.show()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# Sports are physical activities that involve skill, competition, and teamwork.
# They can be played individually or in teams and often require strategy, training, and practice.
# Whether it's soccer, basketball, or tennis, sports help improve physical fitness, boost mental health,
# and teach important life lessons like discipline, perseverance, and teamwork.
# People of all ages enjoy sports, whether for fun, fitness, or competition.
#
# ...
